# %%
from pydub import AudioSegment

sound = AudioSegment.from_wav("C:\\Users\\AleBe\\Documents\\TT\\intento1\\intento\\utils\\audio\\audio\\bass.wav")
sound = sound.set_channels(1)

sound.export("C:\\Users\\AleBe\\Documents\\TT\\intento1\\intento\\utils\\audio\\audio\\bass.wav", format="wav")
# Out:
# C:\Users\AleBe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# <_io.BufferedRandom name='C:\\Users\\AleBe\\Documents\\TT\\intento1\\intento\\utils\\audio\\audio\\bass.wav'>

# %%
"""Obtener informacion de la pista musical en el tiempo y graficar"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import fft, signal
import scipy
from scipy.io.wavfile import read

# Configuración de la gráfica
plt.rcParams['figure.figsize'] = [8, 6]
plt.rcParams['figure.dpi'] = 140

# Leer archivo en format wav
# Fs = frecuencia de sampling del archivo de audio
Fs, song = read("C:\\Users\\AleBe\\Documents\\TT\\intento1\\intento\\utils\\audio\\audio\\bass.wav")

# Seleccion de puntos de inicio y finalizacion de la grafica
time_to_plot = np.arange(Fs * 1, Fs * 1.3, dtype=int)
plt.plot(time_to_plot, song[time_to_plot])
plt.title("Señal de sonido sobre tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Magnitud")
# Out:
# Text(0, 0.5, 'Magnitud')

# %%
N = len(song)
fft = scipy.fft.fft(song)
transform_y = 2.0 / N * np.abs(fft[0:N//2])
transform_x = scipy.fft.fftfreq(N, 1 / Fs)[:N//2]
plt.plot(transform_x, transform_y)
plt.xlabel("Frecuencia (Hz)");

# %%
plt.plot(transform_x, transform_y)
plt.xlim(0, 2000);

# %%
# Usar la función argpartition para encontrar los n-picos más importantes dentro de la señal

todos_los_picos, props = signal.find_peaks(transform_y)

# Encontrar picos con prominencia mínima de 0 y distancia mínima entre picos de 10000
picos, props = signal.find_peaks(transform_y, prominence=0, distance=10000)
n_picos = 15

# Obtener los n_picos picos más grandes a partir de las prominencias
# Explicación útil: https://kanoki.org/2020/01/14/find-k-smallest-and-largest-values-and-its-indices-in-a-numpy-array/
indices_picos_mas_grandes = np.argpartition(props["prominences"], -n_picos)[-n_picos:]
picos_mas_grandes = picos[indices_picos_mas_grandes]

plt.plot(transform_x, transform_y, label="Espectro")
plt.scatter(transform_x[picos_mas_grandes], transform_y[picos_mas_grandes], color="r", zorder=10, label="Picos Restringidos")
plt.xlim(0, 3000)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Usar la función argpartition para encontrar los n-picos más importantes dentro de la señal
# ----> 3 todos_los_picos, props = signal.find_peaks(transform_y)
#       5 # Encontrar picos con prominencia mínima de 0 y distancia mínima entre picos de 10000
#       6 picos, props = signal.find_peaks(transform_y, prominence=0, distance=10000)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\_peak_finding.py:935, in find_peaks(x, height, threshold, distance, prominence, width, wlen, rel_height, plateau_size)
#     729 """
#     730 Find peaks inside a signal based on peak properties.
#     731
#    (...)
#     932 >>> plt.show()
#     933 """
#     934 # _argmaxima1d expects array of dtype 'float64'
# --> 935 x = _arg_x_as_expected(x)
#     936 if distance is not None and distance < 1:
#     937     raise ValueError('`distance` must be greater or equal to 1')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\_peak_finding.py:266, in _arg_x_as_expected(value)
#     264 value = np.asarray(value, order='C', dtype=np.float64)
#     265 if value.ndim != 1:
# --> 266     raise ValueError('`x` must be a 1D array')
#     267 return value
#
# ValueError: `x` must be a 1D array

# %%
# Some parameters
window_length_seconds = 3
window_length_samples = int(window_length_seconds * Fs)
window_length_samples += window_length_samples % 2

# Realizar una transformada de Fourier de tiempo corto
# Frecuencias y tiempos son referencias para graficar/analizar más tarde
# La TFTC es una matriz NxM
frequencies, times, stft = signal.stft(
    song, Fs, nperseg=window_length_samples,
    nfft=window_length_samples, return_onesided=True
)

stft.shape
# Out:
# C:\Users\AleBe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\spectral.py:1964: UserWarning: nperseg = 132300 is greater than input length  = 2, using nperseg = 2
#   warnings.warn('nperseg = {0:d} is greater than input length '
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 9
#       4 window_length_samples += window_length_samples % 2
#       6 # Realizar una transformada de Fourier de tiempo corto
#       7 # Frecuencias y tiempos son referencias para graficar/analizar más tarde
#       8 # La TFTC es una matriz NxM
# ----> 9 frequencies, times, stft = signal.stft(
#      10     song, Fs, nperseg=window_length_samples,
#      11     nfft=window_length_samples, return_onesided=True
#      12 )
#      14 stft.shape
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\spectral.py:1172, in stft(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, boundary, padded, axis)
#    1025 def stft(x, fs=1.0, window='hann', nperseg=256, noverlap=None, nfft=None,
#    1026          detrend=False, return_onesided=True, boundary='zeros', padded=True,
#    1027          axis=-1):
#    1028     r"""
#    1029     Compute the Short Time Fourier Transform (STFT).
#    1030
#    (...)
#    1169     >>> plt.show()
#    1170     """
# -> 1172     freqs, time, Zxx = _spectral_helper(x, x, fs, window, nperseg, noverlap,
#    1173                                         nfft, detrend, return_onesided,
#    1174                                         scaling='spectrum', axis=axis,
#    1175                                         mode='stft', boundary=boundary,
#    1176                                         padded=padded)
#    1178     return freqs, time, Zxx
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\spectral.py:1833, in _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode, boundary, padded)
#    1830     freqs = sp_fft.rfftfreq(nfft, 1/fs)
#    1832 # Perform the windowed FFTs
# -> 1833 result = _fft_helper(x, win, detrend_func, nperseg, noverlap, nfft, sides)
#    1835 if not same_data:
#    1836     # All the same operations on the y data
#    1837     result_y = _fft_helper(y, win, detrend_func, nperseg, noverlap, nfft,
#    1838                            sides)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\signal\spectral.py:1918, in _fft_helper(x, win, detrend_func, nperseg, noverlap, nfft, sides)
#    1916     result = result.real
#    1917     func = sp_fft.rfft
# -> 1918 result = func(result, n=nfft)
#    1920 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\fft\_backend.py:23, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      21 if fn is None:
#      22     return NotImplemented
# ---> 23 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\fft\_pocketfft\basic.py:52, in r2c(forward, x, n, axis, norm, overwrite_x, workers)
#      49     raise TypeError("x must be a real sequence")
#      51 if n is not None:
# ---> 52     tmp, _ = _fix_shape_1d(tmp, n, axis)
#      53 elif tmp.shape[axis] < 1:
#      54     raise ValueError("invalid number of data points ({0}) specified"
#      55                      .format(tmp.shape[axis]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\fft\_pocketfft\helper.py:141, in _fix_shape_1d(x, n, axis)
#     137 if n < 1:
#     138     raise ValueError(
#     139         "invalid number of data points ({0}) specified".format(n))
# --> 141 return _fix_shape(x, (n,), (axis,))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\scipy\fft\_pocketfft\helper.py:131, in _fix_shape(x, shape, axes)
#     128 for n, axis in zip(shape, axes):
#     129     s[axis] = n
# --> 131 z = np.zeros(s, x.dtype)
#     132 z[index] = x[index]
#     133 return z, True
#
# MemoryError: Unable to allocate 21.5 TiB for an array with shape (7452195, 3, 132300) and data type float64

# %%
constellation_map = []

for time_idx, window in enumerate(stft.T):
    # Queremos solo valores reales.
    spectrum = abs(window)
    # Los picos corresponden a características interesantes de la señal
    peaks, props = signal.find_peaks(spectrum, prominence=0, distance=200)

    # Con un máximo de 5 por segmento de tiempo
    n_peaks = 5
    # Obtener los n_peaks picos más grandes a partir de las prominencias
    # Explicación útil de argpartition: https://kanoki.org/2020/01/14/find-k-smallest-and-largest-values-and-its-indices-in-a-numpy-array/
    largest_peaks = np.argpartition(props["prominences"], -n_peaks)[-n_peaks:]
    for peak in peaks[largest_peaks]:
        frequency = frequencies[peak]
        constellation_map.append([time_idx, frequency])

# Transformar [(x, y), ...] en ([x1, x2...], [y1, y2...]) para graficar usando zip
plt.scatter(*zip(*constellation_map));
